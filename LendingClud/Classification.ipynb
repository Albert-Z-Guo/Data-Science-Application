# %% [markdown]
# # Classification
#
# A classification model is trained using preprocessed 2014's data to predict loan default rate.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
import pickle

# %%
df = pd.read_csv('Preprocessed_Data_2014.csv')
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    numtl30dpd  inqlast6mths  accnowdelinq  numactvrevtl  totalcutl  \
# 0         0.0           0.0           0.0           4.0        NaN
# 1         0.0           2.0           0.0           9.0        NaN
# 2         0.0           0.0           0.0           5.0        NaN
# 3         0.0           0.0           0.0           4.0        NaN
# 4         0.0           1.0           0.0           4.0        NaN
#
#    installment revolutil  delinqamnt  mthssincercntil        term  \
# 0       336.64       29%         0.0              NaN   60 months
# 1       321.08     31.6%         0.0              NaN   36 months
# 2       319.08    100.9%         0.0              NaN   60 months
# 3       516.36     76.2%         0.0              NaN   60 months
# 4       260.20     91.9%         0.0              NaN   36 months
#
#         ...        mosinoldrevtlop  avgcurbal  secappmortacc  \
# 0       ...                  244.0    29828.0            NaN
# 1       ...                  290.0     9536.0            NaN
# 2       ...                  170.0    32727.0            NaN
# 3       ...                  136.0     4232.0            NaN
# 4       ...                  148.0     5857.0            NaN
#
#                           emptitle  mthssincelastdelinq    dti  emplength  \
# 0                       MANAGEMENT                  NaN  12.03  10+ years
# 1   Truck Driver Delivery Personel                 42.0  14.92    8 years
# 2        Senior Sales Professional                 17.0   8.31  10+ years
# 3  Programming Analysis Supervisor                 60.0  18.49    6 years
# 4             Technical Specialist                  NaN  34.81   < 1 year
#
#    totcurbal    issued       loanstatus
# 0   149140.0  Dec-2014       Fully Paid
# 1   162110.0  Dec-2014      Charged Off
# 2   261815.0  Dec-2014  In Grace Period
# 3    42315.0  Dec-2014       Fully Paid
# 4    64426.0  Dec-2014      Charged Off
#
# [5 rows x 105 columns]

# %% [markdown]
# ## Feature Engineering

# %%
# separate the categorical and numerical data
all_null_feature=[]
num_feature=[]
ob_feature=[]
for col in df.columns:
    if df[col].isnull().sum()==df.shape[0]:
        all_null_feature.append(col)
    else:
        if df[col].dtype == 'object':
            ob_feature.append(col)
        else:
            num_feature.append(col)

# %%
all_null_feature
# Out:
# ['totalcutl',
#  'mthssincercntil',
#  'totalbalil',
#  'secappcollections12mthsexmed',
#  'secappmthssincelastmajorderog',
#  'allutil',
#  'secappopenactil',
#  'openactil',
#  'maxbalbc',
#  'openrv12m',
#  'secappnumrevaccts',
#  'secappinqlast6mths',
#  'secappopenacc',
#  'secappchargeoffwithin12mths',
#  'verificationstatusjoint',
#  'openil24m',
#  'openil12m',
#  'ilutil',
#  'inqlast12m',
#  'revolbaljoint',
#  'inqfi',
#  'openrv24m',
#  'openacc6m',
#  'secapprevolutil',
#  'secappearliestcrline',
#  'dtijoint',
#  'memberid',
#  'annualincjoint',
#  'secappmortacc']

# %%
ob_feature
# Out:
# ['revolutil',
#  'term',
#  'earliestcrline',
#  'id',
#  'disbursementmethod',
#  'zipcode',
#  'homeownership',
#  'addrstate',
#  'desc',
#  'intrate',
#  'subgrade',
#  'applicationtype',
#  'initialliststatus',
#  'verificationstatus',
#  'grade',
#  'purpose',
#  'emptitle',
#  'emplength',
#  'issued',
#  'loanstatus']

# %%
num_feature
# Out:
# ['numtl30dpd',
#  'inqlast6mths',
#  'accnowdelinq',
#  'numactvrevtl',
#  'installment',
#  'delinqamnt',
#  'openacc',
#  'numbcsats',
#  'bcopentobuy',
#  'fundedamnt',
#  'numacctsever120pd',
#  'numtl120dpd2m',
#  'totalbalexmort',
#  'totalilhighcreditlimit',
#  'accopenpast24mths',
#  'mthssincelastrecord',
#  'numsats',
#  'mthssincelastmajorderog',
#  'tothicredlim',
#  'chargeoffwithin12mths',
#  'mosinrcnttl',
#  'collections12mthsexmed',
#  'pcttlnvrdlq',
#  'mthssincerecentbc',
#  'numtl90gdpd24m',
#  'mthssincerecentrevoldelinq',
#  'mosinrcntrevtlop',
#  'revolbal',
#  'bcutil',
#  'totalrevhilim',
#  'mthssincerecentinq',
#  'mosinoldilacct',
#  'numtloppast12m',
#  'percentbcgt75',
#  'mthssincerecentbcdlq',
#  'numrevtlbalgt0',
#  'totalacc',
#  'numoprevtl',
#  'numactvbctl',
#  'mortacc',
#  'delinq2yrs',
#  'totcollamt',
#  'numrevaccts',
#  'annualinc',
#  'taxliens',
#  'totalbclimit',
#  'loanamnt',
#  'numiltl',
#  'pubrecbankruptcies',
#  'numbctl',
#  'pubrec',
#  'mosinoldrevtlop',
#  'avgcurbal',
#  'mthssincelastdelinq',
#  'dti',
#  'totcurbal']

# %%
features = ob_feature + num_feature
len(features)
# Out:
# 76

# %%
# remove applicationtype, disbursementmethod since it only has one value as 'individual'

features.remove('applicationtype')
features.remove('disbursementmethod')

# %%
# remove 'id', 'issued', 'loanstatus' from ob_feature, since they are indices, and train/test flags and labels

ob_feature.remove('id')
ob_feature.remove('loanstatus')
ob_feature.remove('issued')

# %%
# remove desc' from ob_feature and features

ob_feature.remove('desc')

# %%
features = ob_feature + num_feature
len(features)
# Out:
# 72

# %%
# select all features and delete the last two rows 

df = df[features + ['id', 'loanstatus', 'issued']][:-2]

# %%
df.shape
# Out:
# (235629, 75)

# %%
df['loanstatus'].value_counts()
# Out:
# Fully Paid            172687
# Charged Off            39220
# Current                22321
# Late (31-120 days)       744
# In Grace Period          506
# Late (16-30 days)        150
# Default                    1
# Name: loanstatus, dtype: int64

# %%
df['term'].value_counts()
# Out:
#  36 months    162570
#  60 months     73059
# Name: term, dtype: int64

# %%
# only use loanstatus == 'Fully Paid' or loanstatus == 'Charged Off' and term = '36 months'

df = df.query("loanstatus == 'Fully Paid' or loanstatus == 'Charged Off'")
df = df.query("term == ' 36 months'")
df
# Out:
#        revolutil        term earliestcrline disbursementmethod zipcode  \
# 1          31.6%   36 months       Sep-1989               Cash   937xx
# 4          91.9%   36 months       Aug-2002               Cash   850xx
# 5          59.4%   36 months       Nov-1992               Cash   077xx
# 6          46.4%   36 months       Jan-2001               Cash   144xx
# 8          33.1%   36 months       Jan-1999               Cash   331xx
# 9          20.2%   36 months       May-2009               Cash   208xx
# 10           98%   36 months       Jul-2003               Cash   483xx
#
#        homeownership addrstate  intrate subgrade applicationtype    ...     \
# 1           MORTGAGE        CA    6.99%       A3      Individual    ...
# 4               RENT        AZ   13.66%       C3      Individual    ...
# 5               RENT        NJ   13.66%       C3      Individual    ...
# 6           MORTGAGE        NY   13.66%       C3      Individual    ...
# 8               RENT        FL   17.86%       D5      Individual    ...
# 9               RENT        MD   11.44%       B4      Individual    ...
# 10              RENT        MI   11.99%       B5      Individual    ...
# 11          MORTGAGE        MN   11.99%       B5      Individual    ...
# 12              RENT        WA   14.31%       C4      Individual    ...
# 14          MORTGAGE        KY   10.49%       B3      Individual    ...
# 15              RENT        NY   14.99%       C5      Individual    ...
# 16              RENT        CA   10.49%       B3      Individual    ...
# 17              RENT        AZ   15.99%       D2      Individual    ...
# 18              RENT        FL   14.31%       C4      Individual    ...
# 20          MORTGAGE        TX   12.39%       C1      Individual    ...
# 21               OWN        MN   12.39%       C1      Individual    ...
# 22               OWN        TX   10.49%       B3      Individual    ...
# 23          MORTGAGE        AZ   10.49%       B3      Individual    ...
# 24              RENT        IN   12.99%       C2      Individual    ...
# 25               OWN        FL   11.99%       B5      Individual    ...
# 26          MORTGAGE        IN    9.49%       B2      Individual    ...
# 27              RENT        CA   14.99%       C5      Individual    ...
# 28              RENT        NY   15.99%       D2      Individual    ...
# 30          MORTGAGE        CO   14.31%       C4      Individual    ...
# 32              RENT        CT   12.39%       C1      Individual    ...
# 33          MORTGAGE        NC   16.49%       D3      Individual    ...
# 34          MORTGAGE        AL   10.49%       B3      Individual    ...
# 35               OWN        CA    8.67%       B1      Individual    ...
# 37          MORTGAGE        MS   12.99%       C2      Individual    ...
# 38              RENT        CO   12.39%       C1      Individual    ...
# ...              ...       ...      ...      ...             ...    ...
# 235592          RENT        FL   16.99%       D1      Individual    ...
# 235593          RENT        CA   10.99%       B2      Individual    ...
# 235594          RENT        CA    9.67%       B1      Individual    ...
# 235595           OWN        GA   16.99%       D1      Individual    ...
# 235596      MORTGAGE        TN   13.53%       B5      Individual    ...
# 235597          RENT        CA   14.98%       C3      Individual    ...
# 235599      MORTGAGE        IL   18.25%       D3      Individual    ...
# 235600          RENT        PA   16.99%       D1      Individual    ...
# 235601      MORTGAGE        AL   13.53%       B5      Individual    ...
# 235602      MORTGAGE        IN   21.48%       E2      Individual    ...
# 235603          RENT        FL   15.61%       C4      Individual    ...
# 235604          RENT        CA    9.67%       B1      Individual    ...
# 235605          RENT        MD   13.53%       B5      Individual    ...
# 235606      MORTGAGE        NJ   16.24%       C5      Individual    ...
# 235607          RENT        CA   13.98%       C1      Individual    ...
# 235608      MORTGAGE        PA   17.57%       D2      Individual    ...
# 235609      MORTGAGE        CA    7.90%       A4      Individual    ...
# 235610      MORTGAGE        CA    8.90%       A5      Individual    ...
# 235611          RENT        NC   12.85%       B4      Individual    ...
# 235612      MORTGAGE        OK   16.24%       C5      Individual    ...
# 235613      MORTGAGE        TX    7.90%       A4      Individual    ...
# 235614          RENT        IN   22.40%       E3      Individual    ...
# 22               OWN        TX   10.49%       B3      Individual    ...
# 23          MORTGAGE        AZ   10.49%       B3      Individual    ...
# 24              RENT        IN   12.99%       C2      Individual    ...
# 25               OWN        FL   11.99%       B5      Individual    ...
# 26          MORTGAGE        IN    9.49%       B2      Individual    ...
# 27              RENT        CA   14.99%       C5      Individual    ...
# 28              RENT        NY   15.99%       D2      Individual    ...
# 30          MORTGAGE        CO   14.31%       C4      Individual    ...
# 32              RENT        CT   12.39%       C1      Individual    ...
# 33          MORTGAGE        NC   16.49%       D3      Individual    ...
# 34          MORTGAGE        AL   10.49%       B3      Individual    ...
# 35               OWN        CA    8.67%       B1      Individual    ...
# 37          MORTGAGE        MS   12.99%       C2      Individual    ...
# 38              RENT        CO   12.39%       C1      Individual    ...
# ...              ...       ...      ...      ...             ...    ...
# 235592          RENT        FL   16.99%       D1      Individual    ...
# 235593          RENT        CA   10.99%       B2      Individual    ...
# 235594          RENT        CA    9.67%       B1      Individual    ...
# 235595           OWN        GA   16.99%       D1      Individual    ...
# 235596      MORTGAGE        TN   13.53%       B5      Individual    ...
# 235597          RENT        CA   14.98%       C3      Individual    ...
# 235599      MORTGAGE        IL   18.25%       D3      Individual    ...
# 235600          RENT        PA   16.99%       D1      Individual    ...
# 235601      MORTGAGE        AL   13.53%       B5      Individual    ...
# 235602      MORTGAGE        IN   21.48%       E2      Individual    ...
# 235603          RENT        FL   15.61%       C4      Individual    ...
# 235604          RENT        CA    9.67%       B1      Individual    ...
# 235605          RENT        MD   13.53%       B5      Individual    ...
# 235606      MORTGAGE        NJ   16.24%       C5      Individual    ...
# 235607          RENT        CA   13.98%       C1      Individual    ...
# 235608      MORTGAGE        PA   17.57%       D2      Individual    ...
# 235609      MORTGAGE        CA    7.90%       A4      Individual    ...
# 235610      MORTGAGE        CA    8.90%       A5      Individual    ...
# 235611          RENT        NC   12.85%       B4      Individual    ...
# 235612      MORTGAGE        OK   16.24%       C5      Individual    ...
# 235613      MORTGAGE        TX    7.90%       A4      Individual    ...
# 235614          RENT        IN   22.40%       E3      Individual    ...
# 235617      MORTGAGE        MI   10.99%       B2      Individual    ...
# 235618          RENT        IL   11.99%       B3      Individual    ...
# 235620          RENT        CA   15.61%       C4      Individual    ...
# 235621          RENT        MD    7.90%       A4      Individual    ...
# 235622          RENT        MD   13.53%       B5      Individual    ...
# 235623          RENT        VA   18.25%       D3      Individual    ...
# 235627           OWN        CA    7.90%       A4      Individual    ...
# 235628      MORTGAGE        CA   19.20%       D3      Individual    ...
#
#        numbctl pubrec mosinoldrevtlop avgcurbal mthssincelastdelinq    dti  \
# 1         18.0    0.0           290.0    9536.0                42.0  14.92
# 4          4.0    0.0           148.0    5857.0                 NaN  34.81
# 5         16.0    0.0           265.0    3214.0                 NaN  25.81
# 6          7.0    0.0           167.0   17456.0                46.0  23.63
# 8          6.0    0.0           122.0    1571.0                48.0  22.42
# 9          4.0    0.0            67.0    1267.0                 NaN  14.36
# 10         6.0    0.0           124.0    4745.0                 NaN   8.44
print(df.loanstatus.value_counts())
print(df.loanstatus.value_counts(normalize=True))
# Out:
# 0    140235
# 1     22303
# Name: loanstatus, dtype: int64
# 0    0.862783
# 1    0.137217
# Name: loanstatus, dtype: float64

# %%
# out of time testing set and in-time training set: Oct-Dec as test
issued = list(df['issued'].unique())
issued
# Out:
# ['Dec-2014',
#  'Nov-2014',
#  'Oct-2014',
#  'Sep-2014',
#  'Aug-2014',
#  'Jul-2014',
#  'Jun-2014',
#  'May-2014',
#  'Apr-2014',
#  'Mar-2014',
#  'Feb-2014',
#  'Jan-2014']

# %%
df['train_flag'] = df.issued.apply(lambda x: 0 if x in issued[:3] else 1)
df.train_flag.value_counts()
# Out:
# 1    112550
# 0     49988
# Name: train_flag, dtype: int64

# %%
df.earliestcrline[1].split('-')[1]
# Out:
# '1989'

# %%
# datetime to numeric feature

df.earliestcrline.unique()[:5]
# Out:
# array(['Sep-1989', 'Aug-2002', 'Nov-1992', 'Jan-2001', 'Jan-1999'],
#       dtype=object)

# %%
# convert to number of months to Dec 2014

cl_month = df.earliestcrline.apply(lambda x: x.split('-')[0])
cl_year = df.earliestcrline.apply(lambda x: int(x.split('-')[1]))

# %%
cl_month.unique()
# Out:
# array(['Sep', 'Aug', 'Nov', 'Jan', 'May', 'Jul', 'Oct', 'Jun', 'Dec',
#        'Feb', 'Apr', 'Mar'], dtype=object)

# %%
cl_year.unique()
# Out:
# array([1989, 2002, 1992, 2001, 1999, 2009, 2003, 1998, 1996, 1995, 1993,
#        2010, 2006, 2007, 2000, 2011, 2004, 1994, 1997, 1984, 1988, 2008,
#        2005, 1987, 1991, 1986, 1973, 1985, 1982, 1974, 1979, 1976, 1983,
#        1990, 1978, 1981, 1980, 1977, 1969, 1971, 1967, 1972, 1968, 1962,
#        1975, 1965, 1966, 1963, 1970, 1964, 1958, 1955, 1959, 1961, 1960,
#        1954, 1957, 1949, 1950, 1948, 1953, 1956])

# %%
dict_month = {
    'Jan': 11,
    'Feb': 10,
    'Mar': 9,
    'Apr': 8,
    'May': 7,
    'Jun': 6,
    'Jul': 5,
    'Aug': 4,
    'Sep': 3,
    'Oct': 2,
    'Nov': 1,
    'Dec': 0,
}

# %%
df['earliestcrline_month'] = df.earliestcrline.apply(lambda x: (2014 - int(x.split('-')[1]))*12 + dict_month[x.split('-')[0]])

# %%
df.earliestcrline_month[:5]
# Out:
# 1    303
# 4    148
# 5    265
# 6    167
# 8    191
# Name: earliestcrline_month, dtype: int64

# %%
num_feature.append('earliestcrline_month')
ob_feature.remove('earliestcrline')

# %%
print(len(ob_feature), len(num_feature))
# Out:
# 15 57

# %%
# convert emplength to numeric
print(df['emplength'].isnull().sum())
df['emplength'].unique()
# Out:
# 9644
# array(['8 years', '< 1 year', '10+ years', '2 years', '9 years',
#        '7 years', '5 years', '3 years', '4 years', nan, '1 year',
#        '6 years'], dtype=object)

# %%
df['emplength'].replace('n/a', np.nan, inplace=True)
df['emplength'].replace('< 1 year', 0, inplace=True)
df['emplength'].replace(to_replace='[^0-9]+', value='', inplace=True, regex=True)
df.emplength.fillna(value=-999, inplace=True)
df['emplength'] = df['emplength'].astype(int)

# %%
df.emplength.value_counts()
# Out:
#  10     51133
#  2      14665
#  3      13105
#  0      13054
#  1      10568
#  4       9668
# -999     9644
#  5       9147
#  7       8943
#  6       8205
#  8       8130
#  9       6276
# Name: emplength, dtype: int64

# %%
num_feature.append('emplength')
ob_feature.remove('emplength')
print(len(num_feature), len(ob_feature))
# Out:
# 58 14

# %%
# intrate, revolutil to numeric feature

intrate = df.intrate.apply(lambda x: float(x.replace('%', '')))

# %%
df.intrate = intrate
df.intrate[:2]
# Out:
# 1     6.99
# 4    13.66
# Name: intrate, dtype: float64

# %%
df.revolutil[:3]
# Out:
# 1    31.6%
# 4    91.9%
# 5    59.4%
# Name: revolutil, dtype: object

# %%
revolutil = df.revolutil.apply(lambda x: str(x).replace('%', '')).astype(float)

# %%
df.revolutil= revolutil
df.revolutil[:2]
# Out:
# 1    31.6
# 4    91.9
# Name: revolutil, dtype: float64

# %%
ob_feature.remove('intrate')
num_feature.append('intrate')
ob_feature.remove('revolutil')
num_feature.append('revolutil')

# %%
print(len(ob_feature), len(num_feature))
# Out:
# 12 60

# %%
dict_grade = {
    'A': 1,
    'B': 2,
    'C': 3,
    'D': 4,
    'E': 5,
    'F': 6,
    'G': 7,
}

# %%
df.grade = df.grade.map(dict_grade)

# %%
df.subgrade = df.subgrade.apply(lambda x: (dict_grade[x[0]] - 1)*5 + int(x[1]))

# %%
ob_feature.remove('grade')
num_feature.append('grade')
ob_feature.remove('subgrade')
num_feature.append('subgrade')

# %%
print(len(ob_feature), len(num_feature))
# Out:
# 10 62

# %%
# high cardinality feature encoding

print(df.zipcode.nunique(), df.zipcode.unique()[:5])
# Out:
# 854 ['937xx' '850xx' '077xx' '144xx' '331xx']

# %%
df.zipcode = df.zipcode.apply(lambda x: int(x[0:3]))

# %%
df.zipcode[:5]
# Out:
# 1    937
# 4    850
# 5     77
# 6    144
# 8    331
# Name: zipcode, dtype: int64

# %%
zipcode_freq = df.groupby('zipcode').size().reset_index()
zipcode_freq[:5]
# Out:
#    zipcode    0
# 0        8    1
# 1       10  229
# 2       11   66
# 3       12   69
# 4       13   41

# %%
zipcode_freq.columns = ['zipcode', 'zipcode_freq']

# %%
df = pd.merge(df, zipcode_freq, how='left', on='zipcode')

# %%
ob_feature.remove('zipcode')
num_feature.append('zipcode')
num_feature.append('zipcode_freq')
print(len(ob_feature), len(num_feature))
# Out:
# 9 64

# %%
# emptitle-frequency encoding

emptitle_freq = df.groupby('emptitle').size().reset_index()
emptitle_freq.columns = ['emptitle', 'emptitle_freq']
df = pd.merge(df, emptitle_freq, how='left', on='emptitle')

# %%
ob_feature.remove('emptitle')
num_feature.append('emptitle_freq')
print(len(ob_feature), len(num_feature))
# Out:
# 8 65

# %%
# Addr_state-frequency encoding

emptitle_freq = df.groupby('addrstate').size().reset_index()
emptitle_freq.columns = ['addrstate', 'addrstate_freq']
df = pd.merge(df, emptitle_freq, how='left', on='addrstate')

# %%
ob_feature.remove('addrstate')
num_feature.append('addrstate_freq')
print(len(ob_feature), len(num_feature))
# Out:
# 7 66

# %%
# one-hot encoding

dummy_features = ['homeownership', 'verificationstatus', 'purpose', 'initialliststatus']
df_dummy = pd.get_dummies(df[dummy_features])
OHE_features = list(df_dummy.columns.values)

# %%
len(OHE_features)
# Out:
# 22

# %%
df = pd.concat([df, df_dummy], axis=1)

# %%
df.shape
# Out:
# (162538, 102)

# %%
for feature in dummy_features:
    ob_feature.remove(feature)

# %%
len(ob_feature)
# Out:
# 3

# %%
ob_feature
# Out:
# ['term', 'disbursementmethod', 'applicationtype']

# %%
df['term'].describe()
# Out:
# count         162538
# unique             1
# top        36 months
# freq          162538
# Name: term, dtype: object

# %%
features_selected = num_feature + OHE_features

# %%
len(features_selected)
# Out:
# 88

# %%
features_selected.sort()
features_selected
# Out:
# ['accnowdelinq',
#  'accopenpast24mths',
#  'addrstate_freq',
#  'annualinc',
#  'avgcurbal',
#  'bcopentobuy',
#  'bcutil',
#  'chargeoffwithin12mths',
#  'collections12mthsexmed',
#  'delinq2yrs',
#  'delinqamnt',
#  'dti',
#  'earliestcrline_month',
#  'emplength',
#  'emptitle_freq',
#  'fundedamnt',
#  'grade',
#  'homeownership_ANY',
#  'homeownership_MORTGAGE',
#  'homeownership_OWN',
#  'homeownership_RENT',
#  'initialliststatus_f',
#  'initialliststatus_w',
#  'inqlast6mths',
#  'installment',
#  'intrate',
#  'loanamnt',
#  'mortacc',
#  'mosinoldilacct',
#  'mosinoldrevtlop',
#  'mosinrcntrevtlop',
#  'mosinrcnttl',
#  'mthssincelastdelinq',
#  'mthssincelastmajorderog',
#  'mthssincelastrecord',
#  'mthssincerecentbc',
#  'mthssincerecentbcdlq',
#  'mthssincerecentinq',
#  'mthssincerecentrevoldelinq',
#  'numacctsever120pd',
#  'numactvbctl',
#  'numactvrevtl',
#  'numbcsats',
#  'numbctl',
#  'numiltl',
#  'numoprevtl',
#  'numrevaccts',
#  'numrevtlbalgt0',
#  'numsats',
#  'numtl120dpd2m',
#  'numtl30dpd',
#  'numtl90gdpd24m',
#  'numtloppast12m',
#  'openacc',
#  'pcttlnvrdlq',
#  'percentbcgt75',
#  'pubrec',
#  'pubrecbankruptcies',
#  'purpose_car',
#  'purpose_credit_card',
#  'purpose_debt_consolidation',
#  'purpose_home_improvement',
#  'purpose_house',
#  'purpose_major_purchase',
#  'purpose_medical',
#  'purpose_moving',
#  'purpose_other',
#  'purpose_renewable_energy',
#  'purpose_small_business',
#  'purpose_vacation',
#  'purpose_wedding',
#  'revolbal',
#  'revolutil',
#  'subgrade',
#  'taxliens',
#  'totalacc',
#  'totalbalexmort',
#  'totalbclimit',
#  'totalilhighcreditlimit',
#  'totalrevhilim',
#  'totcollamt',
#  'totcurbal',
#  'tothicredlim',
#  'verificationstatus_Not Verified',
#  'verificationstatus_Source Verified',
#  'verificationstatus_Verified',
#  'zipcode',
#  'zipcode_freq']

# %%
# pick a data point as benchmark
benchmark = df[features_selected].iloc[1,:]
benchmark
# Out:
# accnowdelinq                              0.00
# accopenpast24mths                         6.00
# addrstate_freq                         3889.00
# annualinc                             50000.00
# avgcurbal                              5857.00
# bcopentobuy                             332.00
# bcutil                                   93.20
# chargeoffwithin12mths                     0.00
# collections12mthsexmed                    0.00
# delinq2yrs                                0.00
# delinqamnt                                0.00
# dti                                      34.81
# earliestcrline_month                    148.00
# emplength                                 0.00
# emptitle_freq                            17.00
# fundedamnt                             7650.00
# grade                                     3.00
# homeownership_ANY                         0.00
# homeownership_MORTGAGE                    0.00
# homeownership_OWN                         0.00
# homeownership_RENT                        1.00
# initialliststatus_f                       1.00
# initialliststatus_w                       0.00
# inqlast6mths                              1.00
# installment                             260.20
# intrate                                  13.66
# loanamnt                               7650.00
# mortacc                                   0.00
# mosinoldilacct                          137.00
# mosinoldrevtlop                         148.00
#                                         ...
# purpose_car                               0.00
# purpose_credit_card                       0.00
# purpose_debt_consolidation                1.00
# purpose_home_improvement                  0.00
# purpose_house                             0.00
# purpose_major_purchase                    0.00
# purpose_medical                           0.00
# purpose_moving                            0.00
# purpose_other                             0.00
# purpose_renewable_energy                  0.00
# purpose_small_business                    0.00
# purpose_vacation                          0.00
# purpose_wedding                           0.00
# revolbal                              16822.00
# revolutil                                91.90
# subgrade                                 13.00
# taxliens                                  0.00
# totalacc                                 20.00
# totalbalexmort                        64426.00
# totalbclimit                           4900.00
# totalilhighcreditlimit                64031.00
# totalrevhilim                         18300.00
# totcollamt                                0.00
# totcurbal                             64426.00
# tothicredlim                          82331.00
# verificationstatus_Not Verified           0.00
# verificationstatus_Source Verified        1.00
# verificationstatus_Verified               0.00
# zipcode                                 850.00
# zipcode_freq                            735.00
# Name: 1, Length: 88, dtype: float64

# %%
with open('feature_new.pkl', 'wb') as outfile:
    pickle.dump(benchmark.to_frame().transpose(), outfile)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

# %%
df_train = df.query('train_flag == 1')
df_test = df.query('train_flag == 0')

# %%
print(df_train.shape, df_test.shape)
# Out:
# (112550, 102) (49988, 102)

# %%
df_train[features_selected].shape
# Out:
# (112550, 88)

# %% [markdown]
# ## Modeling Training

# %%
# split training and test data
X_train, X_valid, y_train, y_valid = train_test_split(df_train[features_selected], df_train.loanstatus,
                                                     test_size = 0.3, random_state=2014, stratify=df_train.loanstatus)

# %%
X_test, y_test = df_test[features_selected], df_test.loanstatus

# %%
dtrain = xgb.DMatrix(X_train, y_train, missing=np.NAN)
dvalid = xgb.DMatrix(X_valid, y_valid, missing=np.NAN)
dtest = xgb.DMatrix(X_test, y_test, missing=np.NAN)

# %%
params = {
    'objective': 'binary:logistic',
    'booster': 'gbtree',
    'eta': 0.01,
    'max_depth': 6,
#     'subsample': 0.632,
#     'colsample_bytree': 0.7,
    'seed': 1234,
    'eval_metric': 'auc',
    'min_child_weight': 5
}

watchlist = [(dtrain, 'train'), (dvalid, 'valid')]
num_boost_round = 1500
gbm = xgb.train(params, dtrain, num_boost_round, evals=watchlist, early_stopping_rounds
# [174]	train-auc:0.71991	valid-auc:0.678489
# [175]	train-auc:0.720039	valid-auc:0.678511
# [176]	train-auc:0.720145	valid-auc:0.678539
# [177]	train-auc:0.720244	valid-auc:0.678566
# [178]	train-auc:0.720344	valid-auc:0.678568
# [179]	train-auc:0.720489	valid-auc:0.678627
# [180]	train-auc:0.720613	valid-auc:0.678647
# [181]	train-auc:0.720728	valid-auc:0.678669
# [182]	train-auc:0.72086	valid-auc:0.67871
# [183]	train-auc:0.720972	valid-auc:0.67876
# [184]	train-auc:0.72107	valid-auc:0.678777
# [185]	train-auc:0.7212	valid-auc:0.678804
# [186]	train-auc:0.721313	valid-auc:0.678807
# [187]	train-auc:0.721413	valid-auc:0.678841
# [188]	train-auc:0.721524	valid-auc:0.678849
# [189]	train-auc:0.721632	valid-auc:0.678908
# [190]	train-auc:0.721745	valid-auc:0.678946
# [191]	train-auc:0.721901	valid-auc:0.678981
# [192]	train-auc:0.722019	valid-auc:0.679036
# [193]	train-auc:0.722134	valid-auc:0.679095
# [194]	train-auc:0.722252	valid-auc:0.679155
# [195]	train-auc:0.722364	valid-auc:0.679171
# [196]	train-auc:0.722453	valid-auc:0.679189
# [197]	train-auc:0.722566	valid-auc:0.679264
# [198]	train-auc:0.7227	valid-auc:0.679277
# [199]	train-auc:0.722815	valid-auc:0.679352
# [200]	train-auc:0.722909	valid-auc:0.679402
# [201]	train-auc:0.723029	valid-auc:0.679438
# [202]	train-auc:0.723143	valid-auc:0.679517
# [203]	train-auc:0.723267	valid-auc:0.679562
# [204]	train-auc:0.723398	valid-auc:0.679581
# [205]	train-auc:0.723484	valid-auc:0.679591
# [206]	train-auc:0.723591	valid-auc:0.679652
# [207]	train-auc:0.723702	valid-auc:0.679703
# [208]	train-auc:0.723834	valid-auc:0.679748
# [209]	train-auc:0.724012	valid-auc:0.679809
# [210]	train-auc:0.724107	valid-auc:0.679844
# [211]	train-auc:0.724259	valid-auc:0.679917
# [212]	train-auc:0.724436	valid-auc:0.679965
# [213]	train-auc:0.72455	valid-auc:0.680038
# [214]	train-auc:0.724645	valid-auc:0.68009
# [215]	train-auc:0.724765	valid-auc:0.680111
# [216]	train-auc:0.724841	valid-auc:0.680105
# [217]	train-auc:0.724969	valid-auc:0.680192
# [218]	train-auc:0.725066	valid-auc:0.680228
# [219]	train-auc:0.725165	valid-auc:0.68024
# [220]	train-auc:0.725312	valid-auc:0.680305
# [221]	train-auc:0.725489	valid-auc:0.680367
# [222]	train-auc:0.725586	valid-auc:0.680404
# [223]	train-auc:0.725743	valid-auc:0.680483
# [224]	train-auc:0.725845	valid-auc:0.68052
# [225]	train-auc:0.725963	valid-auc:0.680539
# [226]	train-auc:0.726119	valid-auc:0.680587
# [227]	train-auc:0.726225	valid-auc:0.680627
# [228]	train-auc:0.726349	valid-auc:0.68066
# [229]	train-auc:0.726493	valid-auc:0.680712
# [230]	train-auc:0.726652	valid-auc:0.680791
# [231]	train-auc:0.726751	valid-auc:0.680835
# [232]	train-auc:0.726854	valid-auc:0.680911
# [233]	train-auc:0.727006	valid-auc:0.680987
# [234]	train-auc:0.727154	valid-auc:0.681044
# [235]	train-auc:0.727271	valid-auc:0.681045
# [236]	train-auc:0.727403	valid-auc:0.681093
# [237]	train-auc:0.72754	valid-auc:0.681106
# [238]	train-auc:0.727714	valid-auc:0.681142
# [239]	train-auc:0.727846	valid-auc:0.681216
# [240]	train-auc:0.72799	valid-auc:0.681236
# [241]	train-auc:0.728134	valid-auc:0.681274
# [242]	train-auc:0.728259	valid-auc:0.681326
# [243]	train-auc:0.728406	valid-auc:0.681348
# [244]	train-auc:0.728523	valid-auc:0.681401
# [245]	train-auc:0.728681	valid-auc:0.681458
# [246]	train-auc:0.728808	valid-auc:0.681512
# [247]	train-auc:0.728928	valid-auc:0.681538
# [248]	train-auc:0.729038	valid-auc:0.681538
# [249]	train-auc:0.729158	valid-auc:0.681563
# [250]	train-auc:0.729305	valid-auc:0.681617
# [251]	train-auc:0.72944	valid-auc:0.681667
# [252]	train-auc:0.729552	valid-auc:0.681666
# [253]	train-auc:0.729686	valid-auc:0.681733
# [254]	train-auc:0.72983	valid-auc:0.681759
# [255]	train-auc:0.729955	valid-auc:0.681792
# [256]	train-auc:0.730075	valid-auc:0.681785
# [257]	train-auc:0.730172	valid-auc:0.681798
# [258]	train-auc:0.730265	valid-auc:0.681833
# [259]	train-auc:0.730399	valid-auc:0.681864
# [260]	train-auc:0.730511	valid-auc:0.681859
# [261]	train-auc:0.730619	valid-auc:0.681873
# [262]	train-auc:0.730731	valid-auc:0.681839
# [263]	train-auc:0.730854	valid-auc:0.681921
# [264]	train-auc:0.730942	valid-auc:0.681924
# [265]	train-auc:0.731067	valid-auc:0.681966
# [266]	train-auc:0.731174	valid-auc:0.682002
# [267]	train-auc:0.731283	valid-auc:0.682034
# [268]	train-auc:0.731405	valid-auc:0.682099
# [269]	train-auc:0.731471	valid-auc:0.682126
# [270]	train-auc:0.731592	valid-auc:0.682155
# [271]	train-auc:0.731737	valid-auc:0.682199
# [272]	train-auc:0.731854	valid-auc:0.682208
# [273]	train-auc:0.731986	valid-auc:0.682233
# [274]	train-auc:0.732078	valid-auc:0.682256
# [275]	train-auc:0.732175	valid-auc:0.682271
# [276]	train-auc:0.732312	valid-auc:0.682309
# [277]	train-auc:0.732407	valid-auc:0.682349
# [278]	train-auc:0.73254	valid-auc:0.68238
# [279]	train-auc:0.732664	valid-auc:0.682411
# [280]	train-auc:0.732757	valid-auc:0.682422
# [281]	train-auc:0.732867	valid-auc:0.682441
# [282]	train-auc:0.732984	valid-auc:0.682477
# [283]	train-auc:0.733134	valid-auc:0.682534
# [284]	train-auc:0.733242	valid-auc:0.682575
# [285]	train-auc:0.733375	valid-auc:0.682611
# [286]	train-auc:0.733489	valid-auc:0.682635
# [287]	train-auc:0.733592	valid-auc:0.682667
# [288]	train-auc:0.733729	valid-auc:0.682693
# [289]	train-auc:0.733821	valid-auc:0.682726
# [290]	train-auc:0.733965	valid-auc:0.682798
# [699]	train-auc:0.77964	valid-auc:0.687684
# [700]	train-auc:0.779704	valid-auc:0.687691
# [701]	train-auc:0.779805	valid-auc:0.687726
# [702]	train-auc:0.779935	valid-auc:0.687731
# [703]	train-auc:0.779989	valid-auc:0.687737
# [704]	train-auc:0.780037	valid-auc:0.687744
# [705]	train-auc:0.780099	valid-auc:0.687749
# [706]	train-auc:0.780185	valid-auc:0.687725
# [707]	train-auc:0.780282	valid-auc:0.687712
# [708]	train-auc:0.780393	valid-auc:0.687715
# [709]	train-auc:0.780433	valid-auc:0.68774
# [710]	train-auc:0.780474	valid-auc:0.687728
# [711]	train-auc:0.780557	valid-auc:0.687735
# [712]	train-auc:0.780615	valid-auc:0.687748
# [713]	train-auc:0.780754	valid-auc:0.687773
# [714]	train-auc:0.780822	valid-auc:0.687794
# [715]	train-auc:0.780864	valid-auc:0.687786
# [716]	train-auc:0.78092	valid-auc:0.687816
# [717]	train-auc:0.781034	valid-auc:0.687836
# [718]	train-auc:0.781133	valid-auc:0.68781
# [719]	train-auc:0.781164	valid-auc:0.687804
# [720]	train-auc:0.781255	valid-auc:0.687815
# [721]	train-auc:0.781324	valid-auc:0.687815
# [722]	train-auc:0.781393	valid-auc:0.687812
# [723]	train-auc:0.781448	valid-auc:0.687816
# [724]	train-auc:0.781515	valid-auc:0.687813
# [725]	train-auc:0.781608	valid-auc:0.687846
# [726]	train-auc:0.781693	valid-auc:0.687854
# [727]	train-auc:0.781831	valid-auc:0.687865
# [728]	train-auc:0.781912	valid-auc:0.687869
# [729]	train-auc:0.781959	valid-auc:0.687888
# [730]	train-auc:0.782089	valid-auc:0.687918
# [731]	train-auc:0.782121	valid-auc:0.687915
# [732]	train-auc:0.782175	valid-auc:0.68792
# [733]	train-auc:0.782238	valid-auc:0.687923
# [734]	train-auc:0.782381	valid-auc:0.687922
# [735]	train-auc:0.782454	valid-auc:0.687939
# [736]	train-auc:0.782517	valid-auc:0.687948
# [737]	train-auc:0.78256	valid-auc:0.687936
# [738]	train-auc:0.782621	valid-auc:0.687933
# [739]	train-auc:0.782712	valid-auc:0.687934
# [740]	train-auc:0.782788	valid-auc:0.68794
# [741]	train-auc:0.782844	valid-auc:0.687942
# [742]	train-auc:0.782902	valid-auc:0.687949
# [743]	train-auc:0.783002	valid-auc:0.687947
# [744]	train-auc:0.783112	valid-auc:0.687958
# [745]	train-auc:0.783153	valid-auc:0.68795
# [746]	train-auc:0.783299	valid-auc:0.687967
# [747]	train-auc:0.783352	valid-auc:0.687967
# [748]	train-auc:0.78343	valid-auc:0.687969
# [749]	train-auc:0.783514	valid-auc:0.687958
# [750]	train-auc:0.783545	valid-auc:0.687969
# [751]	train-auc:0.783648	valid-auc:0.687968
# [752]	train-auc:0.783721	valid-auc:0.687977
# [753]	train-auc:0.783764	valid-auc:0.68798
# [754]	train-auc:0.783801	valid-auc:0.687973
# [755]	train-auc:0.783851	valid-auc:0.687953
# [756]	train-auc:0.783896	valid-auc:0.687939
# [757]	train-auc:0.783982	valid-auc:0.687924
# [758]	train-auc:0.784079	valid-auc:0.687928
# [759]	train-auc:0.784224	valid-auc:0.687931
# [760]	train-auc:0.784276	valid-auc:0.687923
# [761]	train-auc:0.78431	valid-auc:0.687911
# [762]	train-auc:0.784398	valid-auc:0.687906
# [763]	train-auc:0.784452	valid-auc:0.687907
# [764]	train-auc:0.784521	valid-auc:0.687897
# [765]	train-auc:0.784612	valid-auc:0.687895
# [766]	train-auc:0.784664	valid-auc:0.687885
# [767]	train-auc:0.784719	valid-auc:0.687886
# [768]	train-auc:0.784756	valid-auc:0.687886
# [769]	train-auc:0.784848	valid-auc:0.687878
# [770]	train-auc:0.78493	valid-auc:0.687857
# [771]	train-auc:0.785004	valid-auc:0.687871
# [772]	train-auc:0.785077	valid-auc:0.687875
# [773]	train-auc:0.785207	valid-auc:0.68789
# [774]	train-auc:0.785243	valid-auc:0.687886
# [775]	train-auc:0.785275	valid-auc:0.687892
# [776]	train-auc:0.785321	valid-auc:0.687897
# [777]	train-auc:0.785434	valid-auc:0.687917
# [778]	train-auc:0.785497	valid-auc:0.687927
# [779]	train-auc:0.78555	valid-auc:0.687933
# [780]	train-auc:0.785621	valid-auc:0.687951
# [781]	train-auc:0.785667	valid-auc:0.68797
# [782]	train-auc:0.785704	valid-auc:0.687955
# [783]	train-auc:0.785749	valid-auc:0.68795
# [784]	train-auc:0.785877	valid-auc:0.687946
# [785]	train-auc:0.785919	valid-auc:0.687942
# [786]	train-auc:0.786015	valid-auc:0.687947
# [787]	train-auc:0.786088	valid-auc:0.687956
# [788]	train-auc:0.786123	valid-auc:0.687953
# [789]	train-auc:0.786204	valid-auc:0.687962
# [790]	train-auc:0.786299	valid-auc:0.687979
# [791]	train-auc:0.786352	valid-auc:0.687962
# [792]	train-auc:0.786402	valid-auc:0.687946
# [793]	train-auc:0.786437	valid-auc:0.687948
# [794]	train-auc:0.786537	valid-auc:0.687944
# [795]	train-auc:0.786585	valid-auc:0.687942
# [796]	train-auc:0.786652	valid-auc:0.687957
# [797]	train-auc:0.786695	valid-auc:0.687952
# [798]	train-auc:0.786775	valid-auc:0.687963
# [799]	train-auc:0.786856	valid-auc:0.687955
# [800]	train-auc:0.786889	valid-auc:0.687945
# [801]	train-auc:0.78696	valid-auc:0.68795
# [802]	train-auc:0.787013	valid-auc:0.687954
# [803]	train-auc:0.787075	valid-auc:0.687964
# Stopping. Best iteration:
# [753]	train-auc:0.783764	valid-auc:0.68798

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import roc_curve, auc
from sklearn import linear_model, datasets
import pylab as pl

def draw_ROC(model, dtrain, dvalid, dtest, y_train, y_valid, y_test):
    probas = model.predict(dvalid, ntree_limit=model.best_ntree_limit)
    probas_1 = model.predict(dtrain, ntree_limit=model.best_ntree_limit)
    probas_2 = model.predict(dtest, ntree_limit=model.best_ntree_limit)
    fpr, tpr, thresholds = roc_curve(y_valid, probas)
    fpr_1, tpr_1, thresholds_1 = roc_curve(y_train, probas_1)
    fpr_2, tpr_2, thresholds_2 = roc_curve(y_test, probas_2)
    roc_auc = auc(fpr, tpr)
    roc_auc_1 = auc(fpr_1, tpr_1)
    roc_auc_2 = auc(fpr_2, tpr_2)
    print('auc_valid', roc_auc)
    print('auc_train', roc_auc_1)
    print('auc_test', roc_auc_2)
    
    plt.figure(figsize=(8, 8))
    plt.plot(fpr, tpr, label='auc_valid = {:.5}'.format(roc_auc), color='r')
    plt.plot(fpr_1, tpr_1, label='auc_train = {:.5}'.format(roc_auc_1), color='g')
    plt.plot(fpr_2, tpr_2, label='auc_test = {:.5}'.format(roc_auc_2), color='b')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Model ROC')
    plt.legend(loc='lower right')
    plt.show()

# %%
draw_ROC(gbm, dtrain, dvalid, dtest, y_train, y_valid, y_test)
# Out:
# auc_valid 0.6879804214533137
# auc_train 0.7837639192829975
# auc_test 0.6957570804551585

# %%
y_pred = gbm.predict(dtest)

# %%
print(y_pred.max(), y_pred.min(), y_pred.mean())
# Out:
# 0.6174121 0.0071251923 0.1359033

# %%
feature_importance = gbm.get_fscore()

# %%
df_feature_importance = pd.DataFrame(list(feature_importance.items()), columns=['feature', 'fscore'])
df_feature_importance['fscore'] = df_feature_importance['fscore'] / df_feature_importance['fscore'].sum()

# %%
df_feature_importance.sort_values(['fscore'], ascending=False, inplace=True)
df_feature_importance
# Out:
#                                feature    fscore
# 7                                  dti  0.050564
# 2                            annualinc  0.044043
# 15                         installment  0.040435
# 6                       mosinoldilacct  0.039874
# 17                     mosinoldrevtlop  0.038725
# 1                              intrate  0.032605
# 5                        emptitle_freq  0.031108
# 12                   accopenpast24mths  0.030814
# 23                   mthssincerecentbc  0.027848
# 11                        tothicredlim  0.027714
# 20                           avgcurbal  0.025416
# 9                              zipcode  0.025202
# 27                         bcopentobuy  0.024828
# 3                        totalrevhilim  0.023919
# 19                  mthssincerecentinq  0.023705
# 29                              bcutil  0.023331
# 24                 mthssincelastdelinq  0.022690
# 21                earliestcrline_month  0.021166
# 40                        zipcode_freq  0.019349
# 32                           revolutil  0.019189
# 10                 mthssincelastrecord  0.019162
# 8              mthssincelastmajorderog  0.017906
# 22                        totalbclimit  0.017826
# 46              totalilhighcreditlimit  0.017131
# 55                      totalbalexmort  0.016302
# 30                         pcttlnvrdlq  0.015607
# 18                mthssincerecentbcdlq  0.015554
# 33                            revolbal  0.015233
# 14                            subgrade  0.014298
# 28                      addrstate_freq  0.014191
# ..                                 ...       ...
# 31                         numactvbctl  0.006975
# 38                           numbcsats  0.006949
# 37                        inqlast6mths  0.006254
# 58                        numactvrevtl  0.006173
# 49                      numrevtlbalgt0  0.005773
# 26                             numsats  0.005479
# 0                                grade  0.004089
# 16                             openacc  0.003581
# 60                          delinq2yrs  0.003421
# 67  verificationstatus_Source Verified  0.002432
# 34              purpose_small_business  0.002085
# 56                 purpose_credit_card  0.002031
# 57              homeownership_MORTGAGE  0.001978
# 68          purpose_debt_consolidation  0.001897
# 39                   numacctsever120pd  0.001737
# 47                       purpose_other  0.001737
# 65                 initialliststatus_f  0.001176
# 51         verificationstatus_Verified  0.001122
# 42                   homeownership_OWN  0.001016
# 66                       numtl120dpd2m  0.000935
# 75            purpose_home_improvement  0.000828
# 64     verificationstatus_Not Verified  0.000722
# 72                      purpose_moving  0.000695
# 69                     purpose_medical  0.000588
# 74               chargeoffwithin12mths  0.000508
# 59                         purpose_car  0.000374
# 70                              pubrec  0.000241
# 63                  pubrecbankruptcies  0.000187
# 71                            taxliens  0.000107
# 73              collections12mthsexmed  0.000053
#
# [76 rows x 2 columns]

# %%
plt.figure(figsize=(32, 32))
df_feature_importance[:20].plot(kind='barh', x='feature', y='fscore', legend=False, figsize=(6, 12))
plt.title('XGBoost Feature Importance')
plt.xlabel('Importance')
# plt.savefig('xgb_feature_importance.png')
# Out:
# Text(0.5,0,'Importance')

# %%
grade_importance = df_feature_importance.query("feature=='grade'")
grade_importance
# Out:
#   feature    fscore
# 0   grade  0.004089

# %%
grade_importance = df_feature_importance.query("feature=='subgrade'")
grade_importance
# Out:
#      feature    fscore
# 14  subgrade  0.014298

# %%
grade_importance = df_feature_importance.query("feature=='intrate'")
grade_importance
# Out:
#    feature    fscore
# 1  intrate  0.032605

# %%
grade_importance = df_feature_importance.query("feature=='loanamnt'")
grade_importance
# Out:
# Empty DataFrame
# Columns: [feature, fscore]
# Index: []

# %%
plt.figure(figsize=(32, 32))
df_feature_importance.plot(kind='barh', x='feature', y='fscore', legend=False, figsize=(6, 12))
plt.title('XGBoost Feature Importance')
plt.xlabel('Importance')
# Out:
# Text(0.5,0,'Importance')

# %%
with open('model_new.pkl', 'wb') as outfile:
    pickle.dump(gbm, outfile)

# %%
feature_old = pd.read_pickle('./Demo Flask/iFlask/fintech/model/feature.pkl')
list(feature_old.columns)
# Out:
# ['loan_amnt',
#  'funded_amnt',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_length',
#  'annual_inc',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'annual_inc_joint',
#  'dti_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_il_6m',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'train_flg',
#  'zip_code_freq',
#  'addr_state_freq',
#  'emp_title_freq',
#  'term_ 36 months',
#  'term_ 60 months',
#  'home_ownership_ANY',
#  'home_ownership_MORTGAGE',
#  'home_ownership_OWN',
#  'home_ownership_RENT',
#  'purpose_car',
#  'purpose_credit_card',
#  'purpose_debt_consolidation',
#  'purpose_home_improvement',
#  'purpose_house',
#  'purpose_major_purchase',
#  'purpose_medical',
#  'purpose_moving',
#  'purpose_other',
#  'purpose_renewable_energy',
#  'purpose_small_business',
#  'purpose_vacation',
#  'purpose_wedding',
#  'addr_state_AK',
#  'addr_state_AL',
#  'addr_state_AR',
#  'addr_state_AZ',
#  'addr_state_CA',
#  'addr_state_CO',
#  'addr_state_CT',
#  'addr_state_DC',
#  'addr_state_DE',
#  'addr_state_FL',
#  'addr_state_GA',
#  'addr_state_HI',
#  'addr_state_IL',
#  'addr_state_IN',
#  'addr_state_KS',
#  'addr_state_KY',
#  'addr_state_LA',
#  'addr_state_MA',
#  'addr_state_MD',
#  'addr_state_ME',
#  'addr_state_MI',
#  'addr_state_MN',
#  'addr_state_MO',
#  'addr_state_MS',
#  'addr_state_MT',
#  'addr_state_NC',
#  'addr_state_NH',
#  'addr_state_NJ',
#  'addr_state_NM',
#  'addr_state_NV',
#  'addr_state_NY',
#  'addr_state_OH',
#  'addr_state_OK',
#  'addr_state_OR',
#  'addr_state_PA',
#  'addr_state_RI',
#  'addr_state_SC',
#  'addr_state_SD',
#  'addr_state_TN',
#  'addr_state_TX',
#  'addr_state_UT',
#  'addr_state_VA',
#  'addr_state_VT',
#  'addr_state_WA',
#  'addr_state_WI',
#  'addr_state_WV',
#  'addr_state_WY',
#  'initial_list_status_f',
#  'initial_list_status_w',
#  'last_credit_pull_d_Apr-2014',
#  'last_credit_pull_d_Apr-2015',
#  'last_credit_pull_d_Apr-2016',
#  'last_credit_pull_d_Aug-2014',
#  'last_credit_pull_d_Aug-2015',
#  'last_credit_pull_d_Dec-2014',
#  'last_credit_pull_d_Dec-2015',
#  'last_credit_pull_d_Feb-2014',
#  'last_credit_pull_d_Feb-2015',
#  'last_credit_pull_d_Feb-2016',
#  'last_credit_pull_d_Jan-2014',
#  'last_credit_pull_d_Jan-2015',
#  'last_credit_pull_d_Jan-2016',
#  'last_credit_pull_d_Jul-2014',
#  'last_credit_pull_d_Jul-2015',
#  'last_credit_pull_d_Jun-2014',
#  'last_credit_pull_d_Jun-2015',
#  'last_credit_pull_d_Mar-2014',
#  'last_credit_pull_d_Mar-2015',
#  'last_credit_pull_d_Mar-2016',
#  'last_credit_pull_d_May-2014',
#  'last_credit_pull_d_May-2015',
#  'last_credit_pull_d_May-2016',
#  'last_credit_pull_d_Nov-2014',
#  'last_credit_pull_d_Nov-2015',
#  'last_credit_pull_d_Oct-2014',
#  'last_credit_pull_d_Oct-2015',
#  'last_credit_pull_d_Sep-2014',
#  'last_credit_pull_d_Sep-2015',
#  'application_type_INDIVIDUAL']

# %%
feature_old
# Out:
#        loan_amnt  funded_amnt  int_rate  installment  grade  sub_grade  \
# 28007      10000       8000.0       0.5       182.49      1          4
#
#        emp_length  annual_inc    dti  delinq_2yrs  \
# 28007           4     75000.0  18.16          0.0
#
#                   ...               last_credit_pull_d_May-2014  \
# 28007             ...                                         0
#
#        last_credit_pull_d_May-2015  last_credit_pull_d_May-2016  \
# 28007                            0                            0
#
#        last_credit_pull_d_Nov-2014  last_credit_pull_d_Nov-2015  \
# 28007                            0                            0
#
#        last_credit_pull_d_Oct-2014  last_credit_pull_d_Oct-2015  \
# 28007                            0                            0
#
#        last_credit_pull_d_Sep-2014  last_credit_pull_d_Sep-2015  \
# 28007                            0                            0
#
#        application_type_INDIVIDUAL
# 28007                            1
#
# [1 rows x 180 columns]

# %%
feature_new = pd.read_pickle('./Demo Flask/iFlask/fintech/model/feature_new.pkl')
list(feature_new.columns)
# Out:
# ['accnowdelinq',
#  'accopenpast24mths',
#  'addrstate_freq',
#  'annualinc',
#  'avgcurbal',
#  'bcopentobuy',
#  'bcutil',
#  'chargeoffwithin12mths',
#  'collections12mthsexmed',
#  'delinq2yrs',
#  'delinqamnt',
#  'dti',
#  'earliestcrline_month',
#  'emplength',
#  'emptitle_freq',
#  'fundedamnt',
#  'grade',
#  'homeownership_ANY',
#  'homeownership_MORTGAGE',
#  'homeownership_OWN',
#  'homeownership_RENT',
#  'initialliststatus_f',
#  'initialliststatus_w',
#  'inqlast6mths',
#  'installment',
#  'intrate',
#  'loanamnt',
#  'mortacc',
#  'mosinoldilacct',
#  'mosinoldrevtlop',
#  'mosinrcntrevtlop',
#  'mosinrcnttl',
#  'mthssincelastdelinq',
#  'mthssincelastmajorderog',
#  'mthssincelastrecord',
#  'mthssincerecentbc',
#  'mthssincerecentbcdlq',
#  'mthssincerecentinq',
#  'mthssincerecentrevoldelinq',
#  'numacctsever120pd',
#  'numactvbctl',
#  'numactvrevtl',
#  'numbcsats',
#  'numbctl',
#  'numiltl',
#  'numoprevtl',
#  'numrevaccts',
#  'numrevtlbalgt0',
#  'numsats',
#  'numtl120dpd2m',
#  'numtl30dpd',
#  'numtl90gdpd24m',
#  'numtloppast12m',
#  'openacc',
#  'pcttlnvrdlq',
#  'percentbcgt75',
#  'pubrec',
#  'pubrecbankruptcies',
#  'purpose_car',
#  'purpose_credit_card',
#  'purpose_debt_consolidation',
#  'purpose_home_improvement',
#  'purpose_house',
#  'purpose_major_purchase',
#  'purpose_medical',
#  'purpose_moving',
#  'purpose_other',
#  'purpose_renewable_energy',
#  'purpose_small_business',
#  'purpose_vacation',
#  'purpose_wedding',
#  'revolbal',
#  'revolutil',
#  'subgrade',
#  'taxliens',
#  'totalacc',
#  'totalbalexmort',
#  'totalbclimit',
#  'totalilhighcreditlimit',
#  'totalrevhilim',
#  'totcollamt',
#  'totcurbal',
#  'tothicredlim',
#  'verificationstatus_Not Verified',
#  'verificationstatus_Source Verified',
#  'verificationstatus_Verified',
#  'zipcode',
#  'zipcode_freq']

# %%
feature_new
# Out:
#    accnowdelinq  accopenpast24mths  addrstate_freq  annualinc  avgcurbal  \
# 1           0.0                6.0          3889.0    50000.0     5857.0
#
#    bcopentobuy  bcutil  chargeoffwithin12mths  collections12mthsexmed  \
# 1        332.0    93.2                    0.0                     0.0
#
#    delinq2yrs      ...       totalilhighcreditlimit  totalrevhilim  \
# 1         0.0      ...                      64031.0        18300.0
#
#    totcollamt  totcurbal  tothicredlim  verificationstatus_Not Verified  \
# 1         0.0    64426.0       82331.0                              0.0
#
#    verificationstatus_Source Verified  verificationstatus_Verified  zipcode  \
# 1                                 1.0                          0.0    850.0
#
#    zipcode_freq
# 1         735.0
#
# [1 rows x 88 columns]

# %%
list(set(feature_old) & set(feature_new))
# Out:
# ['purpose_debt_consolidation',
#  'purpose_other',
#  'purpose_home_improvement',
#  'purpose_wedding',
#  'installment',
#  'dti',
#  'purpose_moving',
#  'purpose_vacation',
#  'purpose_car',
#  'purpose_major_purchase',
#  'grade',
#  'purpose_credit_card',
#  'purpose_small_business',
#  'purpose_medical',
#  'purpose_house',
#  'purpose_renewable_energy']

# %%
# save trained model for further use
pd.read_pickle('./Demo Flask/iFlask/fintech/model/model.pkl')
